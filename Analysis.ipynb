# %% [markdown]
# ### Analysis
#
# This jupyter notebook will:
# - examine clusters and analysis for the two unsupervised learning method

# %%
# importing libraries and modules needed for clustering
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading model
model =  pd.read_pickle('model.pkl')
model
# Out:
#               PLAYER TEAM POSITION       PC1       PC2       PC3       PC4  \
# 0       Aaron Gordon  DEN        F  0.882081  1.494421 -0.103091 -0.276908
# 1      Aaron Holiday  IND        G -3.105932 -3.972688 -0.099769 -0.275749
# 2      Aaron Nesmith  BOS      G-F  0.288487 -4.568325 -1.555126 -1.268215
# 3        Abdel Nader  PHX        F  0.197796 -4.259287 -1.253244 -1.309263
# 4         Al Horford  BOS      C-F  3.188852  0.733974  5.771234 -3.028903
# ..               ...  ...      ...       ...       ...       ...       ...
# 391   Xavier Tillman  MEM        F  5.263395  0.616630 -0.827514 -1.665981
# 392     Yogi Ferrell  LAC        G -0.849503 -6.196595  6.894639 -2.518939
# 393    Yuta Watanabe  TOR      G-F  0.115215 -4.537190 -1.805106  0.628896
# 394      Zach LaVine  CHI      G-F -6.056749  5.995335 -1.423611  0.042179
# 395  Zion Williamson  NOP        F -0.134730  9.304845 -1.553399  2.119779
#
#           PC5       PC6       PC7  KM CLUSTER  GMM CLUSTER
# ...

# %%
# Interpreting K mean clusters
k_clusters = model.drop(['GMM CLUSTER'], axis=1)
k_clusters_pc_mean = k_clusters.groupby('KM CLUSTER').mean()
plt.figure(figsize=(15,15))
sns.heatmap(k_clusters_pc_mean, vmin=-1, vmax=1, center=0, cmap='vlag_r', square=True, annot=True)
# Out:
# <AxesSubplot:ylabel='KM CLUSTER'>

# %%
k_clusters[k_clusters['KM CLUSTER'] == 0].sort_values(by=['PC1', 'PC2', 'PC3', 'PC5', 'PC7'], ascending=False).head(20)
# Out:
#                   PLAYER TEAM POSITION        PC1       PC2       PC3  \
# 335          Rudy Gobert  UTA        C  12.873855  8.385346  0.234198
# 54          Clint Capela  ATL        C  11.996865  7.604640  0.940569
# 121         Enes Freedom  POR        C  11.349243  4.640469  1.483398
# 281    Mitchell Robinson  NYK      C-F  10.692030  1.160703  2.630472
# 82        DeAndre Jordan  BKN        C  10.270398  1.913565  1.445750
# 159          Ivica Zubac  LAC        C  10.267981  3.765455  0.356786
# 69        Daniel Gafford  WAS      F-C   9.728899  0.384740  0.514264
# 87         Deandre Ayton  PHX        C   9.727703  7.799906 -0.083409
# 106           Donta Hall  ORL        C   9.611996 -0.932226  2.496713
# 170         Jakob Poeltl  SAS        C   9.590553  4.861557  0.284585
# 350         Steven Adams  NOP        C   9.558986  3.563386  2.602140
# 367         Tony Bradley  OKC      C-F   9.542795  0.841716  0.812417
# ...

# %%
k_clusters[k_clusters['KM CLUSTER'] == 1].sort_values(by=['PC5'], ascending=False).head(20)
# Out:
#                   PLAYER TEAM POSITION       PC1       PC2       PC3  \
# 225         Kemba Walker  OKC        G -1.544602 -0.448122  5.912303
# 272          Maxi Kleber  DAL        F  2.654486 -1.505496 -1.073625
# 307          P.J. Tucker  MIL        F  1.633215 -5.131241  2.603162
# 72           Danny Green  PHI        G -2.354823 -1.404126 -1.301161
# 78         Davis Bertans  WAS        F -0.591921 -2.498479 -4.257572
# 146         Gorgui Dieng  SAS        C  3.419983 -2.920254  1.975849
# 269  Matthew Dellavedova  CLE        G -1.717622 -6.364928  7.781874
# 46            Cedi Osman  CLE        F  0.183075 -4.827425  5.014799
# 214       Justin Holiday  IND      F-G -2.181634 -1.356089 -2.757691
# 327     Robert Covington  POR        F -0.392738  1.359101 -0.763611
# 368           Tony Snell  ATL        G -1.632580 -4.644225 -2.593250
# 323       Reggie Bullock  NYK      G-F -2.495285 -1.800047 -3.302069
# 17         Armoni Brooks  HOU        G -3.128518 -3.515029 -1.877806
# ...

# %%
k_clusters[k_clusters['KM CLUSTER'] == 2].sort_values(by=['PC2', 'PC7', 'PC3', 'PC4', 'PC6'], ascending=False).head(20)
# Out:
#                     PLAYER TEAM POSITION       PC1        PC2       PC3  \
# 299           Nikola Jokic  DEN        C  1.267944  14.356474  2.619054
# 196            Joel Embiid  PHI      C-F  2.011224  12.008666  0.127056
# 141  Giannis Antetokounmpo  MIL        F -1.022489  11.304216  0.544927
# 220     Karl-Anthony Towns  MIN      C-F  1.819898  10.655708 -0.929568
# 395        Zion Williamson  NOP        F -0.134730   9.304845 -1.553399
# 337      Russell Westbrook  WAS        G -5.498704   9.287998  6.904351
# 213          Julius Randle  NYK      F-C -2.904486   9.249537  0.410074
# 256            Luka Doncic  DAL      F-G -7.139944   9.178708  3.513625
# 14           Anthony Davis  LAL      F-C  1.493251   8.730289  0.070448
# 251           LeBron James  LAL        F -4.186861   8.430257  1.561553
# 221          Kawhi Leonard  LAC        F -4.930372   8.305679 -0.239014
# 231           Kevin Durant  BKN        F -5.007492   8.215086 -1.306907
# ...

# %%
# Interpreting GMM clusters
gmm_clusters = model.drop(['KM CLUSTER'], axis=1)
gmm_clusters_pc_mean = gmm_clusters.groupby('GMM CLUSTER').mean()
plt.figure(figsize=(15,15))
sns.heatmap(gmm_clusters_pc_mean, vmin=-1, vmax=1, center=0, cmap='vlag_r', square=True, annot=True)
# Out:
# <AxesSubplot:ylabel='GMM CLUSTER'>

# %%
gmm_clusters[gmm_clusters['GMM CLUSTER'] == 0].sort_values(by=['PC3', 'PC5', 'PC6', 'PC1', 'PC7', 'PC4'], ascending=False).head(10)
# Out:
#                   PLAYER TEAM POSITION       PC1       PC2       PC3  \
# 269  Matthew Dellavedova  CLE        G -1.717622 -6.364928  7.781874
# 360       Thaddeus Young  CHI        F  2.759759  0.264625  7.173065
# 392         Yogi Ferrell  LAC        G -0.849503 -6.196595  6.894639
# 225         Kemba Walker  OKC        G -1.544602 -0.448122  5.912303
# 4             Al Horford  BOS      C-F  3.188852  0.733974  5.771234
# 118             Ed Davis  MIN      C-F  7.461362 -3.671116  5.142611
# 46            Cedi Osman  CLE        F  0.183075 -4.827425  5.014799
# 5        Al-Farouq Aminu  CHI        F  1.942920 -5.700718  4.822251
# 286          Moses Brown  BOS        C  8.155696 -2.155121  4.751715
# 305      Otto Porter Jr.  ORL        F  0.716493 -4.671051  3.580875
#
#           PC4       PC5       PC6       PC7  GMM CLUSTER
# 269  0.642838  2.640250  0.395090 -0.256412            0
# 360  0.383883  1.946996  0.704021  2.985152            0
# ...

# %%
gmm_clusters[gmm_clusters['GMM CLUSTER'] == 1].sort_values(by=['PC1', 'PC5', 'PC2', 'PC6'], ascending=False).head(10)
# Out:
#             PLAYER TEAM POSITION       PC1       PC2       PC3       PC4  \
# 114  Dwight Howard  PHI      C-F  8.739024  1.521361  0.279331 -2.272299
# 362  Thomas Bryant  WAS      C-F  7.666506  4.081237 -2.492309 -1.866177
# 282       Mo Bamba  ORL        C  6.494846  0.439230 -0.190260 -1.818791
# 235   Kevon Looney  GSW        F  6.404801 -0.213135  0.834283 -0.918246
# 18     Aron Baynes  TOR      C-F  6.278761 -0.980246  0.447687 -0.620040
# 342    Serge Ibaka  LAC        F  6.110759  3.768475 -1.350698 -3.098031
# 178  James Wiseman  GSW        C  5.981029  2.251652 -1.889457  0.269619
# 288   Myles Turner  IND      C-F  5.749734  4.836246 -2.277020  3.026985
# 35     Brook Lopez  MIL        C  5.690583  5.151027 -3.072704 -0.934646
# 236     Khem Birch  TOR        C  5.573408  0.723897 -0.216497  1.388958
#
#           PC5       PC6       PC7  GMM CLUSTER
# 114 -1.236697 -0.038609 -1.236425            1
# 362  1.275553 -3.220083  1.346815            1
# ...

# %%
gmm_clusters[gmm_clusters['GMM CLUSTER'] == 2].sort_values(by=['PC2', 'PC4', 'PC7', 'PC5'], ascending=False).head(10)
# Out:
#                  PLAYER TEAM POSITION       PC1       PC2       PC3       PC4  \
# 12       Andrew Wiggins  GSW        F -2.687518  4.883545 -2.009962  1.559640
# 39          CJ McCollum  POR        G -7.884882  4.360873 -0.404131 -1.533708
# 190        Jerami Grant  DET        F -3.047262  4.070724 -2.762546  0.121638
# 274  Michael Porter Jr.  DEN        F -1.656981  3.938716 -5.309825  0.357939
# 150     Harrison Barnes  SAC        F -0.721526  3.891876 -1.631948 -0.546591
# 302          OG Anunoby  TOR        F -1.583089  3.890812 -3.482111  2.848698
# 91      Dennis Schroder  LAL        G -5.601030  2.998187  2.914423  1.064203
# 280       Miles Bridges  CHA        F  0.097323  2.769323 -3.472732  1.543079
# 275       Mikal Bridges  PHX        F -1.998919  2.604579 -3.767077  0.731654
# 76       Darius Garland  CLE        G -6.362431  2.592409  1.850134  0.555979
#
#           PC5       PC6       PC7  GMM CLUSTER
# 12   0.199792  1.063901  0.454684            2
# ...

# %%
gmm_clusters[gmm_clusters['GMM CLUSTER'] == 3].sort_values(by=['PC2', 'PC3', 'PC7', 'PC6'], ascending=False).head(10)
# Out:
#                 PLAYER TEAM POSITION       PC1       PC2       PC3       PC4  \
# 337  Russell Westbrook  WAS        G -5.498704  9.287998  6.904351  0.370163
# 256        Luka Doncic  DAL      F-G -7.139944  9.178708  3.513625 -1.587461
# 251       LeBron James  LAL        F -4.186861  8.430257  1.561553 -1.782775
# 221      Kawhi Leonard  LAC        F -4.930372  8.305679 -0.239014 -2.449812
# 231       Kevin Durant  BKN        F -5.007492  8.215086 -1.306907 -4.385556
# 30        Bradley Beal  WAS        G -6.287549  8.038585 -0.734552 -0.421143
# 244       Kyrie Irving  BKN        G -6.759551  7.976042  1.193528 -1.454828
# 193       Jimmy Butler  MIA        F -3.952633  7.916208  2.662290  0.374920
# 315        Paul George  LAC        F -5.725444  7.547462 -0.572104 -0.748874
# 176       James Harden  BKN        G -6.862489  7.230448  5.585118 -2.096802
#
#           PC5       PC6       PC7  GMM CLUSTER
# 337 -1.949559  0.632673 -2.005270            3
# ...

# %%
gmm_clusters[gmm_clusters['GMM CLUSTER'] == 4].sort_values(by=['PC7', 'PC5', 'PC4'], ascending=False).head(10)
# Out:
#                PLAYER TEAM POSITION       PC1       PC2       PC3       PC4  \
# 109    Doug McDermott  IND        F -0.808237 -0.585936 -4.967559 -0.356529
# 112   Duncan Robinson  MIA        F -2.484732 -0.413742 -4.736633  0.576462
# 123       Eric Gordon  HOU        G -4.902916 -1.434279 -0.483317 -0.643356
# 271         Max Strus  MIA      G-F -1.243497 -5.602876 -3.691229 -0.831104
# 287     Mychal Mulder  GSW        G -0.640181 -6.126593 -4.112638 -1.486331
# 384   Wayne Ellington  DET        G -2.895157 -3.697502 -3.399859 -0.991707
# 17      Armoni Brooks  HOU        G -3.128518 -3.515029 -1.877806  0.134642
# 363  Tim Hardaway Jr.  DAL      G-F -4.183128  0.495778 -4.413643 -0.082643
# 116     Dylan Windler  CLE      G-F -0.200277 -3.613943 -1.092720  0.485780
# 204      Jordan Poole  GSW        G -3.978574 -2.425509 -2.371958 -1.712350
#
#           PC5       PC6       PC7  GMM CLUSTER
# 109 -2.644026  0.145108  2.961997            4
# ...

# %%
gmm_clusters[gmm_clusters['GMM CLUSTER'] == 5].sort_values(by=['PC3'], ascending=False).head(10)
# Out:
#                PLAYER TEAM POSITION       PC1       PC2       PC3       PC4  \
# 321       Rajon Rondo  LAC        G -3.255169 -3.564492  3.942869 -1.794456
# 277        Mike James  BKN        G -3.871474 -4.078353  3.900296 -1.008869
# 92   Dennis Smith Jr.  DET        G -2.084257 -2.830573  3.891196 -1.404663
# 158         Ish Smith  WAS        G -1.984379 -1.741550  3.390870 -2.216083
# 382        Tyus Jones  MEM        G -4.120395 -4.088154  3.329030 -2.569202
# 89       Delon Wright  SAC        G -3.195484 -0.235515  3.227535  0.107181
# 29     Brad Wanamaker  CHA        G -1.736282 -5.046183  3.195546  0.799393
# 254      Lou Williams  ATL        G -4.180300 -3.125484  3.136087 -2.154878
# 258     Malachi Flynn  TOR        G -2.439843 -3.416596  3.048996 -0.766920
# 296      Nico Mannion  GSW        G -1.603090 -6.353302  2.984094 -0.753914
#
#           PC5       PC6       PC7  GMM CLUSTER
# 321 -0.549538 -1.516312 -3.098144            5
# ...

# %%
gmm_clusters[gmm_clusters['GMM CLUSTER'] == 6].sort_values(by=['PC2', 'PC1', 'PC5', 'PC3', 'PC6'], ascending=False).head(10)
# Out:
#                     PLAYER TEAM POSITION       PC1        PC2       PC3  \
# 299           Nikola Jokic  DEN        C  1.267944  14.356474  2.619054
# 196            Joel Embiid  PHI      C-F  2.011224  12.008666  0.127056
# 141  Giannis Antetokounmpo  MIL        F -1.022489  11.304216  0.544927
# 104       Domantas Sabonis  IND      F-C  3.432684  11.239786  2.926418
# 220     Karl-Anthony Towns  MIN      C-F  1.819898  10.655708 -0.929568
# 300         Nikola Vucevic  CHI        C  4.172533  10.439976  0.559052
# 200      Jonas Valanciunas  MEM        C  8.341097   9.790050 -0.393832
# 395        Zion Williamson  NOP        F -0.134730   9.304845 -1.553399
# 213          Julius Randle  NYK      F-C -2.904486   9.249537  0.410074
# 21             Bam Adebayo  MIA      C-F  3.064523   8.981061  2.514558
#
#           PC4       PC5       PC6       PC7  GMM CLUSTER
# 299 -4.372658  1.822982  0.008531 -1.627360            6
# 196 -3.041007  0.523445  3.787251 -3.116976            6
# ...

# %%
gmm_clusters[gmm_clusters['GMM CLUSTER'] == 7].sort_values(by=['PC1', 'PC2', 'PC7', 'PC3'], ascending=False).head(10)
# Out:
#                 PLAYER TEAM POSITION        PC1       PC2       PC3       PC4  \
# 335        Rudy Gobert  UTA        C  12.873855  8.385346  0.234198  1.080648
# 54        Clint Capela  ATL        C  11.996865  7.604640  0.940569  1.523086
# 121       Enes Freedom  POR        C  11.349243  4.640469  1.483398 -0.739032
# 281  Mitchell Robinson  NYK      C-F  10.692030  1.160703  2.630472  3.454518
# 82      DeAndre Jordan  BKN        C  10.270398  1.913565  1.445750  0.764318
# 159        Ivica Zubac  LAC        C  10.267981  3.765455  0.356786 -2.007991
# 69      Daniel Gafford  WAS      F-C   9.728899  0.384740  0.514264  1.071766
# 106         Donta Hall  ORL        C   9.611996 -0.932226  2.496713 -2.121195
# 170       Jakob Poeltl  SAS        C   9.590553  4.861557  0.284585  0.672420
# 350       Steven Adams  NOP        C   9.558986  3.563386  2.602140  2.072194
#
#           PC5       PC6       PC7  GMM CLUSTER
# 335  2.680176 -3.374364  1.751179            7
# ...
